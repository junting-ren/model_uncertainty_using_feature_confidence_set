# %%
import sys
sys.path.append('../functions')
import numpy as np
#import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
#import torch
import pandas as pd
import multiprocessing
import time
from sklearn.model_selection import ParameterGrid
import linear_sim_func

# %%
# !python3 main_linear.py
# Out:
# Runtime of the program is 1770.6280047893524 seconds

# %% [markdown]
# # One simulation

# %%
n_sim = 500
#closeness_v = [0.5,0.1,0.01,0.001]
#closeness_v = [ -x for x in closeness_v]
N_v = [100]
N_test_v = [100]
p_v = [10]
error_sd_v = [1]
L_v = [0.95]
level_v = [1]
use_true_contour_v = [False]
n_boot_v = [500]
df_result = []
param_grid = {'N': N_v, 'N_test': N_test_v, 'p': p_v , 'error_sd': error_sd_v, 'L': L_v,
              'level': level_v,  'use_true_contour': use_true_contour_v, 'n_boot':n_boot_v}
param_grid = ParameterGrid(param_grid)
for param in param_grid:
    (contain, N, N_test, p, error_sd, level, use_true_contour, contain_scb, 
     contain_CS_scb, L, U, L1, L2, U1, U2, n_points, range_v) = linear_sim_func.sim_linear(param['N'], param['N_test'], param['p'], param['error_sd'], 
                                                                                           param['L'],param['level'],param['use_true_contour'], 
                                                                                           param['n_boot'], return_range = True)
# Out:
# > /Users/juntingren/Library/CloudStorage/OneDrive-Personal/Desktop/CURRENT_RESEARCH/prediction_uncertainty/code/bootstrap_func.py(33)fit_bootstrap()
#      29         mean_boot_l.append(fit_predict(y_boot, X_boot, X_test) )
#      30     mean_boot_l = np.array(mean_boot_l)
#      31     se = np.std(mean_boot_l, axis = 0)
#      32     import pdb; pdb.set_trace()
# ---> 33     return mean, se, mean_boot_l
# ipdb>  mean.shape
# (100,)
# ipdb>  se.shape
# (100,)
# ipdb>  mean_boot_l.shape
# (500, 100)
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user
# Traceback (most recent call last):
#   File "/Users/juntingren/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-1626f677c853>", line 20, in <module>
#     param['n_boot'], return_range = True)
# ValueError: too many values to unpack (expected 17)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/juntingren/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/juntingren/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/juntingren/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/juntingren/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/juntingren/opt/anaconda3/envs/deeplearning/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/juntingren/opt/anaconda3/envs/deeplearning/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/juntingren/opt/anaconda3/envs/deeplearning/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/juntingren/opt/anaconda3/envs/deeplearning/lib/python3.7/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/juntingren/opt/anaconda3/envs/deeplearning/lib/python3.7/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/juntingren/opt/anaconda3/envs/deeplearning/lib/python3.7/posixpath.py", line 429, in _joinrealpath
#     if not islink(newpath):
#   File "/Users/juntingren/opt/anaconda3/envs/deeplearning/lib/python3.7/posixpath.py", line 171, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-2-1626f677c853> in <module>
#      19                                                                                            param['L'],param['level'],param['use_true_contour'],
# ---> 20                                                                                            param['n_boot'], return_range = True)
#
# ValueError: too many values to unpack (expected 17)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2076                         # in the engines. This should return a list of strings.
# -> 2077                         stb = value._render_traceback_()
#    2078                     except Exception:
#
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2078                     except Exception:
#    2079                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2080                                             value, tb, tb_offset=tb_offset)
#    2081
#    2082                     self._showtraceback(etype, value, stb)
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
from matplotlib import pyplot as plt
x = [z[0] for z in range_v]
y = [z[1] for z in range_v]
plt.plot(x,y)
plt.show()
print(L)
print(U)
print(contain)
print(L1)
print(L2)
print(U1)
print(U2)
print(n_points)
# Out:
# 0.9500000000000028
# 0.974
# True
# 0.752
# 0.9500000000000028
# 0.974
# 0.982
# 2

# %% [markdown]
# # Multiple simulations (only works for MacOS)

# %%
df_total = pd.DataFrame()
n_sim = 500
#closeness_v = [0.5,0.1,0.01,0.001]
#closeness_v = [ -x for x in closeness_v]
N_v = [50]
N_test_v = [100]
p_v = [10]
error_sd_v = [1]
L_v = [0.95]
level_v = [1]
use_true_contour_v = [False]
n_boot_v = [500]
df_result = []
param_grid = {'N': N_v, 'N_test': N_test_v, 'p': p_v , 'error_sd': error_sd_v, 'L': L_v,
              'level': level_v,  'use_true_contour': use_true_contour_v, 'n_boot':n_boot_v}
param_grid = ParameterGrid(param_grid)
start = time.time()
for param in param_grid:
    pool_obj = multiprocessing.Pool()
    cur_para = (n_sim*((param['N'], param['N_test'], param['p'], param['error_sd'], \
                      param['L'],param['level'],param['use_true_contour'], param['n_boot']),))
    df_result.append(np.array(pool_obj.starmap(linear_sim_func.sim_linear,cur_para)))
    pool_obj.close()
    pool_obj.join()
    df_ = pd.DataFrame(np.concatenate(df_result, axis = 0), 
                 columns = ["contain", "N", "N_test",
                            "p", "error_sd", "level", "use_true_contour",
                            "contain_scb","contain_CS_scb","Lower_bound",
                            "Upper_bound", "L1", "L2", "U1", "U2", "points_in_e1"])
    df_total = pd.concat([df_total,df_])
    df_total.to_csv('sim_results.csv', index = False)
end = time.time()
print('Runtime of the program is ' + str(end -start) + ' seconds')
# Out:
# KeyboardInterrupt

# %%
df_total[df_total.use_true_contour==0].mean()

# %% [markdown]
# # Using scripts to run (for Windows Ubuntun)

# %%
# !python3 main.py
# Out:
# Runtime of the program is 281.3313100337982 seconds
